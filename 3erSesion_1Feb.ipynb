# %% [markdown]
# ## **Sesión 3** ##
# ## Estadística Aplicada ##
# ### diccionarios-1 febrero ###

# %%
tupla1 = (23, 45, 'libro')

# %%
tupla1 [2]
# Out:
# 'libro'

# %%
alumno1_dic = {'Nombre': 'Juan', 'Apellido':'Perez', 'Edad':23 }

# %%
alumno1_dic
# Out:
# {'Nombre': 'Juan', 'Apellido': 'Perez', 'Edad': 23}

# %%
alumno1_dic ['Nombre']
# Out:
# 'Juan'

# %%
estadistica_g5 = {'Nombre': ['Juan', 'Maria', 'Pedro'], 'Apellido': ['Perez', 'Ruiz', 'Huerta'], 'Edad': [23, 17, 26]}

# %%
estadistica_g5 ['Nombre']
# Out:
# ['Juan', 'Maria', 'Pedro']

# %%
estadistica_g5.keys()
# Out:
# dict_keys(['Nombre', 'Apellido', 'Edad'])

# %%
estadistica_g5.values()
# Out:
# dict_values([['Juan', 'Maria', 'Pedro'], ['Perez', 'Ruiz', 'Huerta'], [23, 17, 26]])

# %% [markdown]
# ## **Pandas** ##
# ## 1 febrero ##

# %%
import numpy as np
import pandas as pd

# %%
alumno1 = ['Juan', 'Pérez', 23]
alumno2 = ['Raúl', 'González', 17]
alumno3 = ['Jimena', 'Rosas', 20]
alumno4 = ['Alejandra', 'Saldaña', 21]

# %%
clase_estadistica = [alumno1, alumno2, alumno3, alumno4]

# %%
clase_estadistica
# Out:
# [['Juan', 'Pérez', 23],
#  ['Raúl', 'González', 17],
#  ['Jimena', 'Rosas', 20],
#  ['Alejandra', 'Saldaña', 21]]

# %%
#ahora la convertimos en un dataframe con pandas
clase_estadistica = pd.DataFrame(clase_estadistica, columns=['Nombre', 'Apellido', 'Edad'])

# %%
clase_estadistica
# Out:
#       Nombre  Apellido  Edad
# 0       Juan     Pérez    23
# 1       Raúl  González    17
# 2     Jimena     Rosas    20
# 3  Alejandra   Saldaña    21

# %%
clase_estadistica.columns
# Out:
# Index(['Nombre', 'Apellido', 'Edad'], dtype='object')

# %%
clase_estadistica.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
clase_estadistica['Edad']*365
# Out:
# 0    8395
# 1    6205
# 2    7300
# 3    7665
# Name: Edad, dtype: int64

# %%
clase_estadistica['Edad en días ']=clase_estadistica['Edad']*365

# %%
clase_estadistica
# Out:
#       Nombre  Apellido  Edad  Edad en días
# 0       Juan     Pérez    23           8395
# 1       Raúl  González    17           6205
# 2     Jimena     Rosas    20           7300
# 3  Alejandra   Saldaña    21           7665

# %%
clase_estadistica['Origen']=['Apodaca','kk','kk','kk']

# %%
clase_estadistica
# Out:
#       Nombre  Apellido  Edad  Edad en días    Origen
# 0       Juan     Pérez    23           8395  Apodaca
# 1       Raúl  González    17           6205       kk
# 2     Jimena     Rosas    20           7300       kk
# 3  Alejandra   Saldaña    21           7665       kk

# %%
#Selección estándar 
# iloc -> Posicion dataframe.iloc[filas,column]
# locis -> Etiqueta/Nombre dataframe.loc[filas,column]
# método
# Condicionales

# %%
clase_estadistica['Edad']
# Out:
# 0    23
# 1    17
# 2    20
# 3    21
# Name: Edad, dtype: int64

# %%
#column 0 a 2
clase_estadistica[0:2]
# Out:
#   Nombre  Apellido  Edad  Edad en días    Origen
# 0   Juan     Pérez    23           8395  Apodaca
# 1   Raúl  González    17           6205       kk

# %%
clase_estadistica[0:2][['Nombre','Edad']]
# Out:
#   Nombre  Edad
# 0   Juan    23
# 1   Raúl    17

# %%
clase_estadistica.iloc[:,1]
# Out:
# 0       Pérez
# 1    González
# 2       Rosas
# 3     Saldaña
# Name: Apellido, dtype: object

# %%
clase_estadistica.iloc[0:2,0]
# Out:
# 0    Juan
# 1    Raúl
# Name: Nombre, dtype: object

# %%
clase_estadistica.loc[:,'Nombre']
# Out:
# 0         Juan
# 1         Raúl
# 2       Jimena
# 3    Alejandra
# Name: Nombre, dtype: object

# %%
clase_estadistica.Nombre
# Out:
# 0         Juan
# 1         Raúl
# 2       Jimena
# 3    Alejandra
# Name: Nombre, dtype: object

# %%
clase_estadistica.Edad
# Out:
# 0    23
# 1    17
# 2    20
# 3    21
# Name: Edad, dtype: int64

# %%
estadistica_g5
# Out:
# {'Nombre': ['Juan', 'Maria', 'Pedro'],
#  'Apellido': ['Perez', 'Ruiz', 'Huerta'],
#  'Edad': [23, 17, 26]}

# %%
estadistica_g5=pd.dataframe(estadistica_g5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3028\2910374063.py in <module>
# ----> 1 estadistica_g5=pd.dataframe(estadistica_g5)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
excel = pd.read_excel("C:/Users/evanp/OneDrive/7mo Semestre/MASVI/ESTADISTICA_PARCIAL.xlsx")

# %%
excel
# Out:
#                Observaciones Sin  AÑO  NSINIEST                        LLAVE  \
# 0       140000150CORTA ESTANCIA1   14    14000015   140000150CORTA ESTANCIA1
# 1       140000150CORTA ESTANCIA1   14    14000015   140000150CORTA ESTANCIA1
# 2      140000270HOSPITALIZACION1   14    14000027  140000270HOSPITALIZACION1
# 3      140000270HOSPITALIZACION1   14    14000027  140000270HOSPITALIZACION1
# 4      140000270HOSPITALIZACION1   14    14000027  140000270HOSPITALIZACION1
# ...                          ...  ...         ...                        ...
# 17533  140606880SERVICIOS F. H.2   14    14060688                  140606882
# 17534  140607360HOSPITALIZACION1   14    14060736                  140607361
# 17535  140607360HOSPITALIZACION1   14    14060736                  140607361
# 17536  140607680HOSPITALIZACION1   14    14060768                  140607681
# 17537  140607680HOSPITALIZACION1   14    14060768                  140607681
#
# ...

# %%
 calificaciones=pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/Calificaciones.csv')

# %%
calificaciones
# Out:
#     Id            Nombre   Apellido  Calficación Final
# 0    1           ANTONIO     GARCIA                 73
# 1    2            MANUEL  FERNANDEZ                 19
# 2    3              JOSE   GONZALEZ                 38
# 3    4             DAVID      PEREZ                 14
# 4    5              JUAN      LOPEZ                 99
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66
# 6    7            JAVIER    SANCHEZ                 46
# 7    8         JOSE LUIS      GOMEZ                 89
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10
# 9   10            CARLOS       RUIZ                 62
# 10  11             JESUS     ALONSO                 94
# 11  12         ALEJANDRO  HERNANDEZ                 17
# 12  13            MIGUEL       DIAZ                 85
# 13  14       JOSE MANUEL  GUTIERREZ                 34
# 14  15            RAFAEL    ALVAREZ                 86
# 15  16      MIGUEL ANGEL     MORENO                100
# ...

# %%
calificaciones.shape
# Out:
# (28, 4)

# %%
calificaciones.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
calificaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 28 non-null     int64
#  1   Nombre             28 non-null     object
#  2   Apellido           28 non-null     object
#  3   Calficación Final  28 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.0+ KB

# %%
calificaciones.describe()
# Out:
#               Id  Calficación Final
# count  28.000000          28.000000
# mean   14.500000          52.000000
# std     8.225975          34.113102
# min     1.000000           1.000000
# 25%     7.750000          18.500000
# 50%    14.500000          48.500000
# 75%    21.250000          85.250000
# max    28.000000         100.000000

# %%
calificaciones.set_index('Apellido')
# Out:
#            Id            Nombre  Calficación Final
# Apellido
# GARCIA      1           ANTONIO                 73
# FERNANDEZ   2            MANUEL                 19
# GONZALEZ    3              JOSE                 38
# PEREZ       4             DAVID                 14
# LOPEZ       5              JUAN                 99
# RODRIGUEZ   6      JOSE ANTONIO                 66
# SANCHEZ     7            JAVIER                 46
# GOMEZ       8         JOSE LUIS                 89
# JIMENEZ     9  FRANCISCO JAVIER                 10
# RUIZ       10            CARLOS                 62
# ALONSO     11             JESUS                 94
# HERNANDEZ  12         ALEJANDRO                 17
# DIAZ       13            MIGUEL                 85
# GUTIERREZ  14       JOSE MANUEL                 34
# ALVAREZ    15            RAFAEL                 86
# MORENO     16      MIGUEL ANGEL                100
# MUÑOZ      17             PEDRO                  1
# ...

# %%
calificaciones.head()
# Out:
#    Id   Nombre   Apellido  Calficación Final
# 0   1  ANTONIO     GARCIA                 73
# 1   2   MANUEL  FERNANDEZ                 19
# 2   3     JOSE   GONZALEZ                 38
# 3   4    DAVID      PEREZ                 14
# 4   5     JUAN      LOPEZ                 99

# %%
calificaciones.rename(columns={'Calficación Final':'cal_final','Apellido': 'apellido'}, inplace=True)

# %%
calificaciones
# Out:
#     Id            Nombre  apelllido  Cal_Final
# 0    1           ANTONIO     GARCIA         73
# 1    2            MANUEL  FERNANDEZ         19
# 2    3              JOSE   GONZALEZ         38
# 3    4             DAVID      PEREZ         14
# 4    5              JUAN      LOPEZ         99
# 5    6      JOSE ANTONIO  RODRIGUEZ         66
# 6    7            JAVIER    SANCHEZ         46
# 7    8         JOSE LUIS      GOMEZ         89
# 8    9  FRANCISCO JAVIER    JIMENEZ         10
# 9   10            CARLOS       RUIZ         62
# 10  11             JESUS     ALONSO         94
# 11  12         ALEJANDRO  HERNANDEZ         17
# 12  13            MIGUEL       DIAZ         85
# 13  14       JOSE MANUEL  GUTIERREZ         34
# 14  15            RAFAEL    ALVAREZ         86
# 15  16      MIGUEL ANGEL     MORENO        100
# 16  17             PEDRO      MUÑOZ          1
# 17  18             PABLO     BLANCO         64
# 18  19             ANGEL        GIL        100
# ...

# %%
calificaciones ['Situation']=np.where (calificaciones['Cal_Final']>=70,'Aprobado','Reprobado')

# %%
calificaciones
# Out:
#     Id            Nombre  apelllido  Cal_Final Situation   Situation
# 0    1           ANTONIO     GARCIA         73   Aprobado   Aprobado
# 1    2            MANUEL  FERNANDEZ         19  Reprobado  Reprobado
# 2    3              JOSE   GONZALEZ         38  Reprobado  Reprobado
# 3    4             DAVID      PEREZ         14  Reprobado  Reprobado
# 4    5              JUAN      LOPEZ         99   Aprobado   Aprobado
# 5    6      JOSE ANTONIO  RODRIGUEZ         66  Reprobado  Reprobado
# 6    7            JAVIER    SANCHEZ         46  Reprobado  Reprobado
# 7    8         JOSE LUIS      GOMEZ         89   Aprobado   Aprobado
# 8    9  FRANCISCO JAVIER    JIMENEZ         10  Reprobado  Reprobado
# 9   10            CARLOS       RUIZ         62  Reprobado  Reprobado
# 10  11             JESUS     ALONSO         94   Aprobado   Aprobado
# 11  12         ALEJANDRO  HERNANDEZ         17  Reprobado  Reprobado
# 12  13            MIGUEL       DIAZ         85   Aprobado   Aprobado
# ...

# %%
calificaciones.groupby('Situation').count() ['Cal_Final']
# Out:
# Situation
# Aprobado     10
# Reprobado    18
# Name: Cal_Final, dtype: int64

# %%
calificaciones.groupby('Situation').mean() ['Cal_Final']
# Out:
# Situation
# Aprobado     90.100000
# Reprobado    30.833333
# Name: Cal_Final, dtype: float64

# %%
excellent=calificaciones[calificaciones['Cal_Final']>=90]

# %%
calificaciones.value_counts('Situation')
# Out:
# Situation
# Reprobado    18
# Aprobado     10
# dtype: int64

# %%
calificaciones.sort_values(['apelllido', 'Nombre'],ascending=[True, True])
# Out:
#     Id            Nombre  apelllido  Cal_Final Situation   Situation
# 19  20            SERGIO    AGUIRRE          2  Reprobado  Reprobado
# 10  11             JESUS     ALONSO         94   Aprobado   Aprobado
# 14  15            RAFAEL    ALVAREZ         86   Aprobado   Aprobado
# 17  18             PABLO     BLANCO         64  Reprobado  Reprobado
# 12  13            MIGUEL       DIAZ         85   Aprobado   Aprobado
# 20  21        JOSE MARIA       DIEZ         29  Reprobado  Reprobado
# 23  24              LUIS  DOMINGUEZ         12  Reprobado  Reprobado
# 1    2            MANUEL  FERNANDEZ         19  Reprobado  Reprobado
# 0    1           ANTONIO     GARCIA         73   Aprobado   Aprobado
# 18  19             ANGEL        GIL        100   Aprobado   Aprobado
# 7    8         JOSE LUIS      GOMEZ         89   Aprobado   Aprobado
# 2    3              JOSE   GONZALEZ         38  Reprobado  Reprobado
# 13  14       JOSE MANUEL  GUTIERREZ         34  Reprobado  Reprobado
# ...
